# %%
from databasetool import sql_to_text_output
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
result = sql_to_text_output.invoke({
    "question" : "How many employees in company" ,
    "database" : "company.db" 
    }
    )
# Out:
# Generated SQL: SELECT
#     COUNT(employee_id)
# FROM
#     employees;

# %%
print("Query:", result["query"])
print("Results:", result["results"])
print("Explanation:", result["explanation"])
# Out:
# Query: SELECT
#     COUNT(employee_id)
# FROM
#     employees;
# Results: [(100,)]
# Explanation: This data shows the total number of employees in your company.
#
# **Key Finding:** There are exactly **100 employees** recorded in your 'employees' table.
#
# **Insights:** This provides a quick snapshot of your current workforce size. Since this is a single count, we cannot observe any trends or patterns over time without more historical data.

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

result  = search_tool.invoke("ipl news")

print(result)

# there are more capabities of the tool
print(search_tool.name)
# Out:
# Latest IPL News ... GT IPL 2026 Auction Review: Gujarat Titans add back-ups and more pace options to already strong squad Indian Premier League ( IPL ) 2025 - News ... IPL 2025: PBKS vs LSG की प्लेइंग 11, आज टॉस कौन जीतेगा Latest IPL News Today: Everything you must know about 2023 IPL with latest news , updates, match previews, live score , predictions, teams and players ... IPL 2025: Latest News and Trends ... The IPL auction became one of the most unpredictable in its history because of surprise player movements and ... Home IPL news ... Tag Archive for: IPL news ... Injured Delhi Daredevils opener Virender Sehwag will not play Saturday ’ s IPL match against ...
# duckduckgo_search

# %%
print(search_tool.args)
# Out:
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %%
print(search_tool.description)
# Out:
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.

# %%
import os
db_path = os.path.join(os.getcwd(), "company.db")

# %%
db_path
# Out:
# 'c:\\Users\\Crashlar\\Desktop\\Research-data-architect-ai\\company.db'

# %%
import os

db_path = os.path.join(os.path.dirname(__file__), "database", "company.db")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import os
# ----> 3 db_path = os.path.join(os.path.dirname(__file__), "database", "company.db")
#
# NameError: name '__file__' is not defined

# %%
d
